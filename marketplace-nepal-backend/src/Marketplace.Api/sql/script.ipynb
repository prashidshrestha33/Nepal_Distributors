-- %% [markdown]
-- # [NepalDistributers]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [NepalDistributers]    Script Date: 12/4/2025 2:12:07 PM ******/
CREATE DATABASE [NepalDistributers]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'NepalDistributers', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL17.MSSQLSERVER\MSSQL\DATA\NepalDistributers.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'NepalDistributers_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL17.MSSQLSERVER\MSSQL\DATA\NepalDistributers_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [NepalDistributers] SET COMPATIBILITY_LEVEL = 170
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [NepalDistributers].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [NepalDistributers] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [NepalDistributers] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [NepalDistributers] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [NepalDistributers] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [NepalDistributers] SET ARITHABORT OFF 
GO
ALTER DATABASE [NepalDistributers] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [NepalDistributers] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [NepalDistributers] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [NepalDistributers] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [NepalDistributers] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [NepalDistributers] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [NepalDistributers] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [NepalDistributers] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [NepalDistributers] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [NepalDistributers] SET  ENABLE_BROKER 
GO
ALTER DATABASE [NepalDistributers] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [NepalDistributers] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [NepalDistributers] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [NepalDistributers] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [NepalDistributers] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [NepalDistributers] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [NepalDistributers] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [NepalDistributers] SET RECOVERY FULL 
GO
ALTER DATABASE [NepalDistributers] SET  MULTI_USER 
GO
ALTER DATABASE [NepalDistributers] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [NepalDistributers] SET DB_CHAINING OFF 
GO
ALTER DATABASE [NepalDistributers] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [NepalDistributers] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [NepalDistributers] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [NepalDistributers] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [NepalDistributers] SET OPTIMIZED_LOCKING = OFF 
GO
EXEC sys.sp_db_vardecimal_storage_format N'NepalDistributers', N'ON'
GO
ALTER DATABASE [NepalDistributers] SET QUERY_STORE = ON
GO
ALTER DATABASE [NepalDistributers] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[audit_logs]

-- %%
USE [NepalDistributers]
GO

-- %%
/****** Object:  Table [dbo].[audit_logs]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[audit_logs](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[actor_user_id] [bigint] NULL,
	[actor_company_id] [bigint] NULL,
	[action] [nvarchar](400) NOT NULL,
	[resource_type] [nvarchar](200) NULL,
	[resource_id] [bigint] NULL,
	[details] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[banners]

-- %%
/****** Object:  Table [dbo].[banners]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[banners](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[title] [nvarchar](400) NULL,
	[image_key] [nvarchar](1000) NULL,
	[link_url] [nvarchar](1000) NULL,
	[target_type] [nvarchar](100) NULL,
	[target_id] [bigint] NULL,
	[start_date] [datetimeoffset](3) NULL,
	[end_date] [datetimeoffset](3) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[brands]

-- %%
/****** Object:  Table [dbo].[brands]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[brands](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](400) NOT NULL,
	[slug] [nvarchar](400) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[categories]

-- %%
/****** Object:  Table [dbo].[categories]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[categories](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](400) NOT NULL,
	[slug] [nvarchar](400) NOT NULL,
	[parent_id] [bigint] NULL,
	[depth] [smallint] NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[chats]

-- %%
/****** Object:  Table [dbo].[chats]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[chats](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[from_user_id] [bigint] NULL,
	[to_user_id] [bigint] NULL,
	[company_id] [bigint] NULL,
	[message] [nvarchar](max) NULL,
	[metadata] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[companies]

-- %%
/****** Object:  Table [dbo].[companies]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[companies](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](400) NOT NULL,
	[contact_person] [nvarchar](400) NULL,
	[mobile_phone] [nvarchar](50) NULL,
	[landline_phone] [nvarchar](50) NULL,
	[registration_document] [nvarchar](max) NULL,
	[company_type] [nvarchar](200) NULL,
	[status] [nvarchar](50) NOT NULL,
	[user_type] [nvarchar](100) NULL,
	[credits] [bigint] NOT NULL,
	[tier] [nvarchar](100) NULL,
	[location] [nvarchar](max) NULL,
	[google_map_location] [geography] NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [char](1) NULL,
	[approve_ts] [datetimeoffset](3) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[companies_category]

-- %%
/****** Object:  Table [dbo].[companies_category]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[companies_category](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](255) NOT NULL,
	[company_type] [nvarchar](50) NULL,
	[description] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[companies_category_assigned]

-- %%
/****** Object:  Table [dbo].[companies_category_assigned]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[companies_category_assigned](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[companies_category_id] [bigint] NULL,
	[company_id] [bigint] NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[credits_transactions]

-- %%
/****** Object:  Table [dbo].[credits_transactions]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[credits_transactions](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[user_id] [bigint] NULL,
	[company_id] [bigint] NULL,
	[delta] [bigint] NOT NULL,
	[reason] [nvarchar](max) NULL,
	[related_order_id] [bigint] NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[csv_imports]

-- %%
/****** Object:  Table [dbo].[csv_imports]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[csv_imports](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[company_id] [bigint] NULL,
	[uploaded_by] [bigint] NULL,
	[filename] [nvarchar](1000) NULL,
	[status] [nvarchar](100) NULL,
	[report] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[feedbacks]

-- %%
/****** Object:  Table [dbo].[feedbacks]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[feedbacks](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[user_id] [bigint] NULL,
	[company_id] [bigint] NULL,
	[subject] [nvarchar](400) NULL,
	[message] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[manufacturers]

-- %%
/****** Object:  Table [dbo].[manufacturers]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[manufacturers](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[company_id] [bigint] NULL,
	[name] [nvarchar](400) NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[notification_mutes]

-- %%
/****** Object:  Table [dbo].[notification_mutes]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[notification_mutes](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[user_id] [bigint] NULL,
	[product_id] [bigint] NULL,
	[category_id] [bigint] NULL,
	[start_date] [datetimeoffset](3) NULL,
	[end_date] [datetimeoffset](3) NULL,
	[mute_until_next] [bit] NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [char](1) NULL,
	[approve_ts] [datetimeoffset](3) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[notifications]

-- %%
/****** Object:  Table [dbo].[notifications]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[notifications](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[user_id] [bigint] NULL,
	[company_id] [bigint] NULL,
	[type] [nvarchar](100) NULL,
	[payload] [nvarchar](max) NULL,
	[is_read] [bit] NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[order_items]

-- %%
/****** Object:  Table [dbo].[order_items]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[order_items](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[order_id] [bigint] NOT NULL,
	[product_id] [bigint] NULL,
	[product_name] [nvarchar](800) NULL,
	[quantity] [decimal](18, 3) NOT NULL,
	[unit_rate] [decimal](12, 2) NOT NULL,
	[total_amount] [decimal](14, 2) NOT NULL,
	[remarks] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[orders]

-- %%
/****** Object:  Table [dbo].[orders]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[orders](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[order_number] [nvarchar](200) NOT NULL,
	[buyer_company_id] [bigint] NULL,
	[seller_company_id] [bigint] NULL,
	[created_by] [bigint] NULL,
	[status] [nvarchar](50) NOT NULL,
	[required_by_date] [date] NULL,
	[shipping_address] [nvarchar](max) NULL,
	[shipping_charge] [decimal](12, 2) NOT NULL,
	[vat_amount] [decimal](12, 2) NOT NULL,
	[grand_total] [decimal](14, 2) NOT NULL,
	[remarks] [nvarchar](max) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [char](1) NULL,
	[approve_ts] [datetimeoffset](3) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[order_number] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[payments]

-- %%
/****** Object:  Table [dbo].[payments]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[payments](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[company_id] [bigint] NULL,
	[user_id] [bigint] NULL,
	[provider] [nvarchar](200) NULL,
	[provider_reference] [nvarchar](1000) NULL,
	[amount] [decimal](12, 2) NULL,
	[status] [nvarchar](50) NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[permissions]

-- %%
/****** Object:  Table [dbo].[permissions]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[permissions](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](200) NOT NULL,
	[description] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[product_images]

-- %%
/****** Object:  Table [dbo].[product_images]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[product_images](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[product_id] [bigint] NOT NULL,
	[s3_key] [nvarchar](1000) NOT NULL,
	[alt_text] [nvarchar](400) NULL,
	[sort_order] [int] NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[products]

-- %%
/****** Object:  Table [dbo].[products]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[products](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[sku] [nvarchar](200) NULL,
	[name] [nvarchar](800) NOT NULL,
	[description] [nvarchar](max) NULL,
	[short_description] [nvarchar](max) NULL,
	[category_id] [bigint] NULL,
	[subcategory_id] [bigint] NULL,
	[subsubcategory_id] [bigint] NULL,
	[brand_id] [bigint] NULL,
	[manufacturer_id] [bigint] NULL,
	[rate] [decimal](12, 2) NOT NULL,
	[hs_code] [nvarchar](100) NULL,
	[status] [nvarchar](50) NOT NULL,
	[is_featured] [bit] NOT NULL,
	[seo_title] [nvarchar](400) NULL,
	[seo_description] [nvarchar](max) NULL,
	[attributes] [nvarchar](max) NULL,
	[created_by] [bigint] NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [char](1) NULL,
	[approve_ts] [datetimeoffset](3) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[quote_items]

-- %%
/****** Object:  Table [dbo].[quote_items]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[quote_items](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[quote_id] [bigint] NOT NULL,
	[product_id] [bigint] NULL,
	[quantity] [decimal](18, 3) NULL,
	[unit_rate] [decimal](12, 2) NULL,
	[total_amount] [decimal](14, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[quotes]

-- %%
/****** Object:  Table [dbo].[quotes]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[quotes](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[quote_number] [nvarchar](200) NULL,
	[order_id] [bigint] NULL,
	[quoted_by] [bigint] NULL,
	[expires_at] [datetimeoffset](3) NULL,
	[shipping_charge] [decimal](12, 2) NOT NULL,
	[status] [nvarchar](50) NOT NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [char](1) NULL,
	[approve_ts] [datetimeoffset](3) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[quote_number] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[role_permissions]

-- %%
/****** Object:  Table [dbo].[role_permissions]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[role_permissions](
	[role_id] [int] NOT NULL,
	[permission_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[role_id] ASC,
	[permission_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[roles]

-- %%
/****** Object:  Table [dbo].[roles]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[roles](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](200) NOT NULL,
	[description] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[seo_pages]

-- %%
/****** Object:  Table [dbo].[seo_pages]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[seo_pages](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[slug] [nvarchar](400) NULL,
	[title] [nvarchar](400) NULL,
	[content] [nvarchar](max) NULL,
	[type] [nvarchar](100) NULL,
	[target_id] [bigint] NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[slug] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[user_roles]

-- %%
/****** Object:  Table [dbo].[user_roles]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[user_roles](
	[user_id] [bigint] NOT NULL,
	[role_id] [int] NOT NULL,
	[assigned_at] [datetimeoffset](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[user_id] ASC,
	[role_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 12/4/2025 2:12:08 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[company_id] [bigint] NULL,
	[email] [nvarchar](320) NOT NULL,
	[password_hash] [nvarchar](200) NULL,
	[full_name] [nvarchar](400) NULL,
	[phone] [nvarchar](50) NULL,
	[role] [nvarchar](50) NOT NULL,
	[status] [nvarchar](50) NOT NULL,
	[credits] [bigint] NOT NULL,
	[tier] [nvarchar](100) NULL,
	[created_at] [datetimeoffset](3) NOT NULL,
	[updated_at] [datetimeoffset](3) NOT NULL,
	[approve_dt] [datetimeoffset](3) NOT NULL,
	[approve_fg] [char](1) NULL,
	[last_login_at] [datetimeoffset](3) NULL,
	[google_id] [nvarchar](200) NULL,
	[facebook_id] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__audit_log__creat__2DE6D218]

-- %%
ALTER TABLE [dbo].[audit_logs] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__banners__created__25518C17]

-- %%
ALTER TABLE [dbo].[banners] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__brands__created___70DDC3D8]

-- %%
ALTER TABLE [dbo].[brands] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__categorie__depth__6C190EBB]

-- %%
ALTER TABLE [dbo].[categories] ADD  DEFAULT ((1)) FOR [depth]
GO

-- %% [markdown]
-- # [DF__categorie__creat__6D0D32F4]

-- %%
ALTER TABLE [dbo].[categories] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__categorie__updat__6E01572D]

-- %%
ALTER TABLE [dbo].[categories] ADD  DEFAULT (sysdatetimeoffset()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__chats__created_a__3493CFA7]

-- %%
ALTER TABLE [dbo].[chats] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__companies__statu__40F9A68C]

-- %%
ALTER TABLE [dbo].[companies] ADD  DEFAULT ('active') FOR [status]
GO

-- %% [markdown]
-- # [DF__companies__credi__41EDCAC5]

-- %%
ALTER TABLE [dbo].[companies] ADD  DEFAULT ((0)) FOR [credits]
GO

-- %% [markdown]
-- # [DF__companies__creat__42E1EEFE]

-- %%
ALTER TABLE [dbo].[companies] ADD  DEFAULT (sysutcdatetime()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__companies__updat__43D61337]

-- %%
ALTER TABLE [dbo].[companies] ADD  DEFAULT (sysutcdatetime()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__companies__appro__44CA3770]

-- %%
ALTER TABLE [dbo].[companies] ADD  DEFAULT (sysutcdatetime()) FOR [approve_ts]
GO

-- %% [markdown]
-- # [DF__companies__creat__52593CB8]

-- %%
ALTER TABLE [dbo].[companies_category] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__companies__updat__534D60F1]

-- %%
ALTER TABLE [dbo].[companies_category] ADD  DEFAULT (sysdatetimeoffset()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__companies__creat__5629CD9C]

-- %%
ALTER TABLE [dbo].[companies_category_assigned] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__companies__updat__571DF1D5]

-- %%
ALTER TABLE [dbo].[companies_category_assigned] ADD  DEFAULT (sysdatetimeoffset()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__credits_t__creat__282DF8C2]

-- %%
ALTER TABLE [dbo].[credits_transactions] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__csv_impor__creat__2B0A656D]

-- %%
ALTER TABLE [dbo].[csv_imports] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__feedbacks__creat__37703C52]

-- %%
ALTER TABLE [dbo].[feedbacks] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__manufactu__creat__73BA3083]

-- %%
ALTER TABLE [dbo].[manufacturers] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__notificat__mute___208CD6FA]

-- %%
ALTER TABLE [dbo].[notification_mutes] ADD  DEFAULT ((0)) FOR [mute_until_next]
GO

-- %% [markdown]
-- # [DF__notificat__creat__2180FB33]

-- %%
ALTER TABLE [dbo].[notification_mutes] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__notificat__appro__22751F6C]

-- %%
ALTER TABLE [dbo].[notification_mutes] ADD  DEFAULT (sysdatetimeoffset()) FOR [approve_ts]
GO

-- %% [markdown]
-- # [DF__notificat__is_re__1CBC4616]

-- %%
ALTER TABLE [dbo].[notifications] ADD  DEFAULT ((0)) FOR [is_read]
GO

-- %% [markdown]
-- # [DF__notificat__creat__1DB06A4F]

-- %%
ALTER TABLE [dbo].[notifications] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__order_ite__quant__0F624AF8]

-- %%
ALTER TABLE [dbo].[order_items] ADD  DEFAULT ((0)) FOR [quantity]
GO

-- %% [markdown]
-- # [DF__order_ite__unit___10566F31]

-- %%
ALTER TABLE [dbo].[order_items] ADD  DEFAULT ((0)) FOR [unit_rate]
GO

-- %% [markdown]
-- # [DF__order_ite__total__114A936A]

-- %%
ALTER TABLE [dbo].[order_items] ADD  DEFAULT ((0)) FOR [total_amount]
GO

-- %% [markdown]
-- # [DF__orders__status__06CD04F7]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT ('draft') FOR [status]
GO

-- %% [markdown]
-- # [DF__orders__shipping__07C12930]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT ((0)) FOR [shipping_charge]
GO

-- %% [markdown]
-- # [DF__orders__vat_amou__08B54D69]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT ((0)) FOR [vat_amount]
GO

-- %% [markdown]
-- # [DF__orders__grand_to__09A971A2]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT ((0)) FOR [grand_total]
GO

-- %% [markdown]
-- # [DF__orders__created___0A9D95DB]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__orders__updated___0B91BA14]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT (sysdatetimeoffset()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__orders__approve___0C85DE4D]

-- %%
ALTER TABLE [dbo].[orders] ADD  DEFAULT (sysdatetimeoffset()) FOR [approve_ts]
GO

-- %% [markdown]
-- # [DF__payments__status__30C33EC3]

-- %%
ALTER TABLE [dbo].[payments] ADD  DEFAULT ('pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__payments__create__31B762FC]

-- %%
ALTER TABLE [dbo].[payments] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__product_i__sort___7E37BEF6]

-- %%
ALTER TABLE [dbo].[product_images] ADD  DEFAULT ((0)) FOR [sort_order]
GO

-- %% [markdown]
-- # [DF__product_i__creat__7F2BE32F]

-- %%
ALTER TABLE [dbo].[product_images] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__products__rate__76969D2E]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT ((0)) FOR [rate]
GO

-- %% [markdown]
-- # [DF__products__status__778AC167]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT ('pending_approval') FOR [status]
GO

-- %% [markdown]
-- # [DF__products__is_fea__787EE5A0]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT ((0)) FOR [is_featured]
GO

-- %% [markdown]
-- # [DF__products__create__797309D9]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__products__update__7A672E12]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT (sysdatetimeoffset()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__products__approv__7B5B524B]

-- %%
ALTER TABLE [dbo].[products] ADD  DEFAULT (sysdatetimeoffset()) FOR [approve_ts]
GO

-- %% [markdown]
-- # [DF__quotes__shipping__151B244E]

-- %%
ALTER TABLE [dbo].[quotes] ADD  DEFAULT ((0)) FOR [shipping_charge]
GO

-- %% [markdown]
-- # [DF__quotes__status__160F4887]

-- %%
ALTER TABLE [dbo].[quotes] ADD  DEFAULT ('open') FOR [status]
GO

-- %% [markdown]
-- # [DF__quotes__created___17036CC0]

-- %%
ALTER TABLE [dbo].[quotes] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__quotes__approve___17F790F9]

-- %%
ALTER TABLE [dbo].[quotes] ADD  DEFAULT (sysdatetimeoffset()) FOR [approve_ts]
GO

-- %% [markdown]
-- # [DF__seo_pages__creat__02FC7413]

-- %%
ALTER TABLE [dbo].[seo_pages] ADD  DEFAULT (sysdatetimeoffset()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__user_role__assig__693CA210]

-- %%
ALTER TABLE [dbo].[user_roles] ADD  DEFAULT (sysdatetimeoffset()) FOR [assigned_at]
GO

-- %% [markdown]
-- # [NepalDistributers]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [NepalDistributers] SET  READ_WRITE 
GO
